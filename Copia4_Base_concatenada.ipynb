# %% [markdown]
# <a href="https://colab.research.google.com/github/anaperez10/AnaliticaIII-Salud/blob/main/Copia4_Base_concatenada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EJERCICIO PRÁCTICO - ANALÍTICA EN SALUD: CANTIDAD DE CIRUGÍAS**

# %% [markdown]
# Generacion de base de datos post pandemia a trabajar (2021-2022)

# %%
#Conexión con colab
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
from unicodedata import normalize
from sklearn.model_selection import RandomizedSearchCV
# Out:
# Mounted at /content/drive

# %%
# Leer cada una de las bases de datos.
cx = pd.read_csv('/content/drive/MyDrive/Curso Analitica 3/cxpost.csv')
cronicos = pd.read_csv('/content/drive/MyDrive/Curso Analitica 3/cronicospost.csv')
usuarios = pd.read_csv('/content/drive/MyDrive/Curso Analitica 3/usuariospost.csv')
cx.head(5)
# Out:
#    Unnamed: 0  YEAR    MES  CODIGO SERVICIO HABILITACION  \
# 0         854  2021  ENERO                         207.0
# 1         855  2021  ENERO                         215.0
# 2         856  2021  ENERO                         207.0
# 3         857  2021  ENERO                         207.0
# 4         858  2021  ENERO                         207.0
#
#   SERVICIO HABILITACION TIPO IDENTIFICACION  NRODOC FECHA NACIMIENTO  \
# 0    cirugia ortopedica                  CC  308384       1971-02-10
# 1     cirugia urologica                  CC  308384       1971-02-10
# 2    cirugia ortopedica                  CC  308384       1971-02-10
# 3    cirugia ortopedica                  CC  308384       1971-02-10
# 4    cirugia ortopedica                  CC  308384       1971-02-10
#
#       REGIMEN  CODIGO EPS  ... COD DIAGNOSTICO POSTQUIRURGICO  \
# 0  subsidiado      1415.0  ...                           T818
# 1  subsidiado      1415.0  ...                           N359
# 2  subsidiado      1415.0  ...                           M869
# 3  subsidiado      1415.0  ...                           M866
# 4  subsidiado      1415.0  ...                           M864
#
#                           DIAGNOSTICO POSTQUIRURGICO      TIPO DE HERIDA  \
# 0  OTRAS COMPLICACIONES DE PROCEDIMIENTOS NO CLAS...         contaminada
# 1                  ESTRECHEZ URETRAL NO ESPECIFICADA  limpia contaminada
# 2                      OSTEOMIELITIS NO ESPECIFICADA         contaminada
# 3                       OTRAS OSTEOMIELITIS CRONICAS               sucia
# 4         OSTEOMIELITIS CRONICA CON DRENAJE DEL SENO         contaminada
#
#   TIPO AISLAMIENTO  COMPLICACIONES CATEGORIA COMPLICACION ESPECIALIDAD  \
# 0              NaN           False                    3.0    ortopedia
# 1       Protector;           False                    2.0     urologia
# 2       Protector;           False                    3.0    ortopedia
# 3       Protector;           False                    2.0    ortopedia
# 4       Protector;           False                    2.0    ortopedia
#
#         SEDE      IDCX ADMISION
# 0  LEON XIII  109718.0  5466001
# 1  LEON XIII  109856.0  5466001
# 2  LEON XIII  110056.0  5466001
# 3  LEON XIII  110349.0  5466001
# 4  LEON XIII  110480.0  5466001
#
# [5 rows x 41 columns]

# %%
cx.head(5)
# Out:
#    Unnamed: 0  YEAR    MES  CODIGO SERVICIO HABILITACION  \
# 0         854  2021  ENERO                         207.0
# 1         855  2021  ENERO                         215.0
# 2         856  2021  ENERO                         207.0
# 3         857  2021  ENERO                         207.0
# 4         858  2021  ENERO                         207.0
#
#   SERVICIO HABILITACION TIPO IDENTIFICACION  NRODOC FECHA NACIMIENTO  \
# 0    cirugia ortopedica                  CC  308384       1971-02-10
# 1     cirugia urologica                  CC  308384       1971-02-10
# 2    cirugia ortopedica                  CC  308384       1971-02-10
# 3    cirugia ortopedica                  CC  308384       1971-02-10
# 4    cirugia ortopedica                  CC  308384       1971-02-10
#
#       REGIMEN  CODIGO EPS  ... COD DIAGNOSTICO POSTQUIRURGICO  \
# 0  subsidiado      1415.0  ...                           T818
# 1  subsidiado      1415.0  ...                           N359
# 2  subsidiado      1415.0  ...                           M869
# 3  subsidiado      1415.0  ...                           M866
# 4  subsidiado      1415.0  ...                           M864
#
#                           DIAGNOSTICO POSTQUIRURGICO      TIPO DE HERIDA  \
# 0  OTRAS COMPLICACIONES DE PROCEDIMIENTOS NO CLAS...         contaminada
# 1                  ESTRECHEZ URETRAL NO ESPECIFICADA  limpia contaminada
# 2                      OSTEOMIELITIS NO ESPECIFICADA         contaminada
# 3                       OTRAS OSTEOMIELITIS CRONICAS               sucia
# 4         OSTEOMIELITIS CRONICA CON DRENAJE DEL SENO         contaminada
#
#   TIPO AISLAMIENTO  COMPLICACIONES CATEGORIA COMPLICACION ESPECIALIDAD  \
# 0              NaN           False                    3.0    ortopedia
# 1       Protector;           False                    2.0     urologia
# 2       Protector;           False                    3.0    ortopedia
# 3       Protector;           False                    2.0    ortopedia
# 4       Protector;           False                    2.0    ortopedia
#
#         SEDE      IDCX ADMISION
# 0  LEON XIII  109718.0  5466001
# 1  LEON XIII  109856.0  5466001
# 2  LEON XIII  110056.0  5466001
# 3  LEON XIII  110349.0  5466001
# 4  LEON XIII  110480.0  5466001
#
# [5 rows x 41 columns]

# %% [markdown]
# Se hace de nuevo una depuracion de la base de datos de cirugia, en donde los elementos post cirugia se eliminan.

# %%
cx.columns.values
# Out:
# array(['Unnamed: 0', 'YEAR', 'MES', 'CODIGO SERVICIO HABILITACION',
#        'SERVICIO HABILITACION', 'TIPO IDENTIFICACION', 'NRODOC',
#        'FECHA NACIMIENTO', 'REGIMEN', 'CODIGO EPS',
#        'DESCRIPCION EPS VALIDADA', 'FECHA ORDEN', 'ORIGEN ORDEN',
#        'ORIGEN ADMSION', 'QUIROFANO', 'TIPO PROCEDIMIENTO',
#        'FECHA PREANESTESIA', 'ASA', 'FECHA CIRUGIA', 'TIPO DE ANESTESIA',
#        'FECHA RECUPERACION CX', 'VIA', 'COD CUPS',
#        'NOMBRE DE PROCEDIMIENTO', 'PROCEDIMIENTO 0256',
#        'COD DIAGNOSTICO PREQUIRURGICO', 'DESCRIPCION PREQUIRURGICO',
#        'CIE 10 TERCER CARACTER', 'DESCRIPCION TERCER CARACTER',
#        'CAPITULO CIE10', 'NOMBRE CAPITULO',
#        'COD DIAGNOSTICO POSTQUIRURGICO', 'DIAGNOSTICO POSTQUIRURGICO',
#        'TIPO DE HERIDA', 'TIPO AISLAMIENTO', 'COMPLICACIONES',
#        'CATEGORIA COMPLICACION', 'ESPECIALIDAD', 'SEDE', 'IDCX',
#        'ADMISION'], dtype=object)

# %%
cronicos.head(5)
# Out:
#    Unnamed: 0  YEAR    MES Fecha diligenciamiento           Hora  Atención  \
# 0       12827  2021  ENERO             2021-01-01  12:13:45 a.m.   5465666
# 1       12828  2021  ENERO             2021-01-01   8:01:46 p.m.   5459773
# 2       12829  2021  ENERO             2021-01-03   8:41:16 p.m.   5456426
# 3       12831  2021  ENERO             2021-01-04   8:33:34 a.m.   4306788
# 4       12833  2021  ENERO             2021-01-04   8:40:58 a.m.   5325410
#
#    Ingreso Tipo  NRODOC  Peso  ...  VO2 - Máxima Cantidad de Oxígeno  \
# 0  3668418   CC  310176  56.0  ...                           13.8855
# 1  3670506   CC  312214  39.0  ...                           35.3671
# 2  3670496   CC  311627  88.0  ...                           12.5212
# 3  3669378   CC  307827  65.2  ...                           17.2497
# 4  3670145   CC  312431  55.0  ...                           13.0032
#
#    Índice de Fragilidad Groningen Calificación (Índice de Fragilidad)  \
# 0                             9.0                              Frágil
# 1                             8.0                              Frágil
# 2                             9.0                              Frágil
# 3                            10.0                              Frágil
# 4                             4.0                              Normal
#
#    Tiempo en Segundos (Apoyo Monopodal)  Calificación (Apoyo Monopodal)  \
# 0                                     9                   Malo - Fragil
# 1                                    10                       Aceptable
# 2                                     0                   Malo - Fragil
# 3                                     0                   Malo - Fragil
# 4                                     6                   Malo - Fragil
#
#    Tiempo en Segundos (Recorrer 5 metros)  Velocidad (m/s)  \
# 0                                       6             0.83
# 1                                       6             0.83
# 2                                       0             0.00
# 3                                       9             0.56
# 4                                       8             0.63
#
#    Calificación Velocidad  Requiere cita de morbilidad  Ambito según el médico
# 0              Deficiente                           Si            Domiciliario
# 1              Deficiente                           Si            Domiciliario
# 2           Malo - Frágil                           No            Domiciliario
# 3           Malo - Frágil                           Si            Domiciliario
# 4              Deficiente                           No            Domiciliario
#
# [5 rows x 36 columns]

# %%
cronicos.columns.values
# Out:
# array(['Unnamed: 0', 'YEAR', 'MES', 'Fecha diligenciamiento', 'Hora',
#        'Atención', 'Ingreso', 'Tipo', 'NRODOC', 'Peso', 'Talla', 'IMC',
#        'Clasificación IMC', 'Saturación de Oxígeno (%)',
#        'Perímetro Muslo', 'Perímetro Cintura', 'Pliegue Triceps',
#        'Pliegue Abdomen', 'Pliegue Muslo', 'Sumatoria Pliegues',
#        'Presión Arterial Sistólica', 'Presión Arterial Diastólica',
#        'Frecuencia Cardíaca en reposo',
#        'Auto-calificacion Nivel de Ejercicio', 'Constantes',
#        'METS -Índice Metabólico', 'VO2 - Máxima Cantidad de Oxígeno',
#        'Índice de Fragilidad Groningen',
#        'Calificación (Índice de Fragilidad)',
#        'Tiempo en Segundos (Apoyo Monopodal)',
#        'Calificación (Apoyo Monopodal)',
#        'Tiempo en Segundos (Recorrer 5 metros)', 'Velocidad (m/s)',
#        'Calificación Velocidad', 'Requiere cita de morbilidad',
#        'Ambito según el médico'], dtype=object)

# %% [markdown]
# Tratamiento para CRONICOS

# %%
cronicos.columns= cronicos.columns.str.lower()
cx.columns= cx.columns.str.lower()

# %%
usuarios
# Out:
#        Unnamed: 0    mes   año  nrodoc sexo  edad        municipio  \
# 0          101490  enero  2021  311028    m    69         sabaneta
# 1          101491  enero  2021  310961    m    75            bello
# 2          101492  enero  2021  311235    f    85         medellin
# 3          101493  enero  2021  307090    f    88         medellin
# 4          101494  enero  2021  310309    f    79         medellin
# ...           ...    ...   ...     ...  ...   ...              ...
# 82416      183906  junio  2022  307482    f    81         medellin
# 82417      183907  junio  2022  313801    f    23  sin información
# 82418      183908  junio  2022  307738    f    78         medellin
# 82419      183909  junio  2022  311656    m    82         medellin
# 82420      183910  junio  2022  309230    m    65         envigado
#
#       ciclo_vital quinquenio
# 0           vejez      65-69
# 1           vejez      75-79
# 2           vejez      85-89
# 3           vejez      85-89
# 4           vejez      75-79
# ...           ...        ...
# 82416       vejez      80-84
# 82417    juventud      20-24
# 82418       vejez      75-79
# 82419       vejez      80-84
# 82420       vejez      65-69
#
# [82421 rows x 9 columns]

# %%
cronicos.head()
# Out:
#    unnamed: 0  year    mes fecha diligenciamiento           hora  atención  \
# 0       12827  2021  ENERO             2021-01-01  12:13:45 a.m.   5465666
# 1       12828  2021  ENERO             2021-01-01   8:01:46 p.m.   5459773
# 2       12829  2021  ENERO             2021-01-03   8:41:16 p.m.   5456426
# 3       12831  2021  ENERO             2021-01-04   8:33:34 a.m.   4306788
# 4       12833  2021  ENERO             2021-01-04   8:40:58 a.m.   5325410
#
#    ingreso tipo  nrodoc  peso  ...  vo2 - máxima cantidad de oxígeno  \
# 0  3668418   CC  310176  56.0  ...                           13.8855
# 1  3670506   CC  312214  39.0  ...                           35.3671
# 2  3670496   CC  311627  88.0  ...                           12.5212
# 3  3669378   CC  307827  65.2  ...                           17.2497
# 4  3670145   CC  312431  55.0  ...                           13.0032
#
#    índice de fragilidad groningen calificación (índice de fragilidad)  \
# 0                             9.0                              Frágil
# 1                             8.0                              Frágil
# 2                             9.0                              Frágil
# 3                            10.0                              Frágil
# 4                             4.0                              Normal
#
#    tiempo en segundos (apoyo monopodal)  calificación (apoyo monopodal)  \
# 0                                     9                   Malo - Fragil
# 1                                    10                       Aceptable
# 2                                     0                   Malo - Fragil
# 3                                     0                   Malo - Fragil
# 4                                     6                   Malo - Fragil
#
#    tiempo en segundos (recorrer 5 metros)  velocidad (m/s)  \
# 0                                       6             0.83
# 1                                       6             0.83
# 2                                       0             0.00
# 3                                       9             0.56
# 4                                       8             0.63
#
#    calificación velocidad  requiere cita de morbilidad  ambito según el médico
# 0              Deficiente                           Si            Domiciliario
# 1              Deficiente                           Si            Domiciliario
# 2           Malo - Frágil                           No            Domiciliario
# 3           Malo - Frágil                           Si            Domiciliario
# 4              Deficiente                           No            Domiciliario
#
# [5 rows x 36 columns]

# %%
cronicos1 = cronicos.groupby(['nrodoc'])[['unnamed: 0']].count().reset_index()
cronicos1.rename(columns = {'unnamed: 0':'cantidad de registros en cronicos'},inplace=True)
cronicos1
# Out:
#       nrodoc  cantidad de registros en cronicos
# 0     306221                                  3
# 1     306222                                  3
# 2     306223                                  1
# 3     306225                                  3
# 4     306230                                  4
# ...      ...                                ...
# 5012  314216                                  1
# 5013  314217                                  2
# 5014  314218                                  1
# 5015  314219                                  4
# 5016  314220                                  1
#
# [5017 rows x 2 columns]

# %%
cronicos2 = pd.merge(cronicos1,cronicos, on = 'nrodoc',how = 'inner')
cronicos2
# Out:
#        nrodoc  cantidad de registros en cronicos  unnamed: 0  year  \
# 0      306221                                  3       23612  2021
# 1      306221                                  3       28919  2021
# 2      306221                                  3       34630  2022
# 3      306222                                  3       20495  2021
# 4      306222                                  3       24778  2021
# ...       ...                                ...         ...   ...
# 25284  314219                                  4       35092  2022
# 25285  314219                                  4       35447  2022
# 25286  314219                                  4       35448  2022
# 25287  314219                                  4       38462  2022
# 25288  314220                                  1       35088  2022
#
#               mes fecha diligenciamiento           hora  atención  ingreso  \
# 0      SEPTIEMBRE             2021-09-14  10:57:03 a.m.   5782373  4021570
# 1       DICIEMBRE             2021-12-20  10:47:00 a.m.   5902300  4155406
# 2           MARZO             2022-03-23   8:53:44 a.m.   6009224  4267035
# 3           JULIO             2021-07-23  11:59:12 a.m.   5716669  3952526
# 4         OCTUBRE             2021-10-08   1:51:01 p.m.   5814923  4055969
# ...           ...                    ...            ...       ...      ...
# 25284       MARZO             2022-03-31   8:12:14 a.m.   6031834  4278122
# 25285       ABRIL             2022-04-06   7:33:13 a.m.   6048896  4286525
# 25286       ABRIL             2022-04-18  11:58:27 a.m.   6048896  4286525
# 25287        MAYO             2022-05-24   5:51:12 p.m.   6048896  4286525
# 25288       MARZO             2022-03-31   6:45:11 a.m.   6031757  4277875
#
#       tipo  ...  vo2 - máxima cantidad de oxígeno  \
# 0       CC  ...                            5.6854
# 1       CC  ...                            5.3935
# 2       CC  ...                            6.0060
# 3       CC  ...                           23.8318
# 4       CC  ...                           22.3044
# ...    ...  ...                               ...
# 25284   CC  ...                           15.2261
# 25285   CC  ...                           15.4745
# 25286   CC  ...                           15.4745
# 25287   CC  ...                           14.8445
# 25288   CC  ...                           22.6807
#
#        índice de fragilidad groningen  calificación (índice de fragilidad)  \
# 0                                 6.0                               Frágil
# 1                                 4.0                               Normal
# 2                                 2.0                               Normal
# 3                                 3.0                               Normal
# 4                                 1.0                               Normal
# ...                               ...                                  ...
# 25284                             9.0                               Frágil
# 25285                             5.0                               Frágil
# 25286                             5.0                               Frágil
# 25287                             5.0                               Frágil
# 25288                             7.0                               Frágil
#
#       tiempo en segundos (apoyo monopodal)  calificación (apoyo monopodal)  \
# 0                                        0                   Malo - Fragil
# 1                                        0                   Malo - Fragil
# 2                                        0                   Malo - Fragil
# 3                                        0                   Malo - Fragil
# 4                                        0                   Malo - Fragil
# ...                                    ...                             ...
# 25284                                    0                   Malo - Fragil
# 25285                                    0                   Malo - Fragil
# 25286                                    0                   Malo - Fragil
# 25287                                    0                   Malo - Fragil
# 25288                                   10                       Aceptable
#
#        tiempo en segundos (recorrer 5 metros)  velocidad (m/s)  \
# 0                                           9             0.56
# 1                                           9             0.56
# 2                                           4             1.25
# 3                                           0             0.00
# 4                                           5             1.00
# ...                                       ...              ...
# 25284                                       5             1.00
# 25285                                       8             0.63
# 25286                                       8             0.63
# 25287                                       8             0.63
# 25288                                       4             1.25
#
#        calificación velocidad  requiere cita de morbilidad  \
# 0               Malo - Frágil                           No
# 1               Malo - Frágil                           No
# 2                   Aceptable                           No
# 3               Malo - Frágil                           No
# 4                   Aceptable                           No
# ...                       ...                          ...
# 25284               Aceptable                           No
# 25285              Deficiente                           No
# 25286              Deficiente                           Si
# 25287              Deficiente                           No
# 25288               Aceptable                           No
#
#        ambito según el médico
# 0                 Ambulatorio
# 1                 Ambulatorio
# 2                 Ambulatorio
# 3                 Ambulatorio
# 4                 Ambulatorio
# ...                       ...
# 25284             Ambulatorio
# 25285            Domiciliario
# 25286            Domiciliario
# 25287            Domiciliario
# 25288             Ambulatorio
#
# [25289 rows x 37 columns]

# %%
cronicos2=cronicos2.drop_duplicates(subset=['nrodoc'])
cronicos2.shape
# Out:
# (5017, 37)

# %%
cronicos2 = cronicos2.drop(['tipo','clasificación imc','calificación (índice de fragilidad)','calificación (apoyo monopodal)','calificación velocidad','unnamed: 0'], axis=1)
cronicos2
# Out:
#        nrodoc  cantidad de registros en cronicos  year         mes  \
# 0      306221                                  3  2021  SEPTIEMBRE
# 3      306222                                  3  2021       JULIO
# 6      306223                                  1  2021       ENERO
# 7      306225                                  3  2021  SEPTIEMBRE
# 10     306230                                  4  2021       MARZO
# ...       ...                                ...   ...         ...
# 25280  314216                                  1  2022       MARZO
# 25281  314217                                  2  2022     FEBRERO
# 25283  314218                                  1  2022       MARZO
# 25284  314219                                  4  2022       MARZO
# 25288  314220                                  1  2022       MARZO
#
#       fecha diligenciamiento           hora  atención  ingreso   peso  talla  \
# 0                 2021-09-14  10:57:03 a.m.   5782373  4021570   75.0  143.0
# 3                 2021-07-23  11:59:12 a.m.   5716669  3952526   72.0  164.0
# 6                 2021-01-28   7:28:15 a.m.   5240438  3669950   72.0  162.0
# 7                 2021-09-17  10:14:25 a.m.   5793621  4026277   56.0  150.0
# 10                2021-03-03   9:00:45 a.m.   5540086  3752542   72.0  162.0
# ...                      ...            ...       ...      ...    ...    ...
# 25280             2022-03-17   6:47:49 a.m.   6013543  4260764   91.0  134.0
# 25281             2022-02-07   8:02:14 a.m.   5975763  4210294   56.0  150.0
# 25283             2022-03-04   8:21:00 a.m.   5990784  4244375  102.0  172.0
# 25284             2022-03-31   8:12:14 a.m.   6031834  4278122   71.0  148.0
# 25288             2022-03-31   6:45:11 a.m.   6031757  4277875   83.5  167.0
#
#        ...  auto-calificacion nivel de ejercicio  constantes  \
# 0      ...                                     1         0.0
# 3      ...                                     1         0.0
# 6      ...                                     1         0.0
# 7      ...                                     1         0.0
# 10     ...                                     1         0.0
# ...    ...                                   ...         ...
# 25280  ...                                     1         0.0
# 25281  ...                                     1         0.0
# 25283  ...                                     1         0.0
# 25284  ...                                     1         0.0
# 25288  ...                                     1         0.0
#
#        mets -índice metabólico  vo2 - máxima cantidad de oxígeno  \
# 0                       1.6244                            5.6854
# 3                       6.8091                           23.8318
# 6                       2.7069                            9.4741
# 7                       7.0087                           24.5304
# 10                      3.7469                           13.1141
# ...                        ...                               ...
# 25280                   4.0344                           14.1204
# 25281                   4.1187                           14.4155
# 25283                   6.4584                           22.6044
# 25284                   4.3503                           15.2261
# 25288                   6.4802                           22.6807
#
#        índice de fragilidad groningen  tiempo en segundos (apoyo monopodal)  \
# 0                                 6.0                                     0
# 3                                 3.0                                     0
# 6                                15.0                                     0
# 7                                 6.0                                     3
# 10                                5.0                                     0
# ...                               ...                                   ...
# 25280                             1.0                                     2
# 25281                             8.0                                     6
# 25283                             4.0                                    10
# 25284                             9.0                                     0
# 25288                             7.0                                    10
#
#        tiempo en segundos (recorrer 5 metros)  velocidad (m/s)  \
# 0                                           9             0.56
# 3                                           0             0.00
# 6                                           0             0.00
# 7                                           3             1.67
# 10                                          9             0.56
# ...                                       ...              ...
# 25280                                       5             1.00
# 25281                                       6             0.83
# 25283                                       5             1.00
# 25284                                       5             1.00
# 25288                                       4             1.25
#
#        requiere cita de morbilidad  ambito según el médico
# 0                               No             Ambulatorio
# 3                               No             Ambulatorio
# 6                               Si            Domiciliario
# 7                               No             Ambulatorio
# 10                              No             Ambulatorio
# ...                            ...                     ...
# 25280                           No             Ambulatorio
# 25281                           No             Ambulatorio
# 25283                           No             Ambulatorio
# 25284                           No             Ambulatorio
# 25288                           No             Ambulatorio
#
# [5017 rows x 31 columns]

# %% [markdown]
# Tratamiento para USUARIOS

# %%
usuarios1 = cronicos.groupby(['nrodoc'])[['unnamed: 0']].count().reset_index()
usuarios1.rename(columns = {'unnamed: 0':'cantidad de registros en el sistema'},inplace=True)
usuarios1
# Out:
#       nrodoc  cantidad de registros en el sistema
# 0     306221                                    3
# 1     306222                                    3
# 2     306223                                    1
# 3     306225                                    3
# 4     306230                                    4
# ...      ...                                  ...
# 5012  314216                                    1
# 5013  314217                                    2
# 5014  314218                                    1
# 5015  314219                                    4
# 5016  314220                                    1
#
# [5017 rows x 2 columns]

# %%
usuarios2 = pd.merge(usuarios1,usuarios, on = 'nrodoc',how = 'inner')
usuarios2
# Out:
#        nrodoc  cantidad de registros en el sistema  Unnamed: 0      mes   año  \
# 0      306221                                    3      103403    enero  2021
# 1      306221                                    3      108198  febrero  2021
# 2      306221                                    3      112932    marzo  2021
# 3      306221                                    3      117540    abril  2021
# 4      306221                                    3      122067     mayo  2021
# ...       ...                                  ...         ...      ...   ...
# 80280  314219                                    4      183799    junio  2022
# 80281  314220                                    1      170479    marzo  2022
# 80282  314220                                    1      174973    abril  2022
# 80283  314220                                    1      179407     mayo  2022
# 80284  314220                                    1      183800    junio  2022
#
#       sexo  edad municipio ciclo_vital quinquenio
# 0        f    82  medellin       vejez      80-84
# 1        f    82  medellin       vejez      80-84
# 2        f    82  medellin       vejez      80-84
# 3        f    82  medellin       vejez      80-84
# 4        f    82  medellin       vejez      80-84
# ...    ...   ...       ...         ...        ...
# 80280    m    63  medellin       vejez      60-64
# 80281    m    69  medellin       vejez      65-69
# 80282    m    69  medellin       vejez      65-69
# 80283    m    69  medellin       vejez      65-69
# 80284    m    69  medellin       vejez      65-69
#
# [80285 rows x 10 columns]

# %%
usuarios2 = usuarios2.drop(['ciclo_vital','quinquenio','Unnamed: 0'],axis=1)

# %% [markdown]
# Tratamiento a CIRUGIAS

# %%
cx
# Out:
#       unnamed: 0  year    mes  codigo servicio habilitacion  \
# 0            854  2021  ENERO                         207.0
# 1            855  2021  ENERO                         215.0
# 2            856  2021  ENERO                         207.0
# 3            857  2021  ENERO                         207.0
# 4            858  2021  ENERO                         207.0
# ...          ...   ...    ...                           ...
# 1082        2365  2022   MAYO                         207.0
# 1083        2366  2022   MAYO                         207.0
# 1084        2367  2022  JUNIO                         213.0
# 1085        2368  2022  JUNIO                         203.0
# 1086        2369  2022  JUNIO                           NaN
#
#             servicio habilitacion tipo identificacion  nrodoc  \
# 0              cirugia ortopedica                  CC  308384
# 1               cirugia urologica                  CC  308384
# 2              cirugia ortopedica                  CC  308384
# 3              cirugia ortopedica                  CC  308384
# 4              cirugia ortopedica                  CC  308384
# ...                           ...                 ...     ...
# 1082           cirugia ortopedica                  CC  312770
# 1083           cirugia ortopedica                  CC  313334
# 1084  cirugia plastica y estetica                  CC  307306
# 1085              cirugia general                  CC  307270
# 1086                          NaN                  CC  313523
#
#      fecha nacimiento       regimen  codigo eps  ...  \
# 0          1971-02-10    subsidiado      1415.0  ...
# 1          1971-02-10    subsidiado      1415.0  ...
# 2          1971-02-10    subsidiado      1415.0  ...
# 3          1971-02-10    subsidiado      1415.0  ...
# 4          1971-02-10    subsidiado      1415.0  ...
# ...               ...           ...         ...  ...
# 1082       1950-05-07  contributivo      1791.0  ...
# 1083       1947-03-28  contributivo      1791.0  ...
# 1084       1936-10-15  contributivo      3289.0  ...
# 1085       1956-12-22  contributivo      1791.0  ...
# 1086       1979-05-11  contributivo      1791.0  ...
#
#      cod diagnostico postquirurgico  \
# 0                              T818
# 1                              N359
# 2                              M869
# 3                              M866
# 4                              M864
# ...                             ...
# 1082                           G560
# 1083                           G560
# 1084                           C443
# 1085                           K439
# 1086                           L600
#
#                              diagnostico postquirurgico      tipo de herida  \
# 0     OTRAS COMPLICACIONES DE PROCEDIMIENTOS NO CLAS...         contaminada
# 1                     ESTRECHEZ URETRAL NO ESPECIFICADA  limpia contaminada
# 2                         OSTEOMIELITIS NO ESPECIFICADA         contaminada
# 3                          OTRAS OSTEOMIELITIS CRONICAS               sucia
# 4            OSTEOMIELITIS CRONICA CON DRENAJE DEL SENO         contaminada
# ...                                                 ...                 ...
# 1082                        SINDROME DEL TUNEL CARPIANO              limpia
# 1083                        SINDROME DEL TUNEL CARPIANO              limpia
# 1084  TUMOR MALIGNO DE LA PIEL DE OTRAS PARTES Y DE ...              limpia
# 1085  OTRAS HERNIAS VENTRALES Y LAS NO ESPECIFICADAS...              limpia
# 1086                                      UNA ENCARNADA  limpia contaminada
#
#      tipo aislamiento  complicaciones categoria complicacion  \
# 0                 NaN           False                    3.0
# 1          Protector;           False                    2.0
# 2          Protector;           False                    3.0
# 3          Protector;           False                    2.0
# 4          Protector;           False                    2.0
# ...               ...             ...                    ...
# 1082              NaN           False                    3.0
# 1083              NaN           False                    3.0
# 1084              NaN           False                    2.0
# 1085              NaN           False                    2.0
# 1086              NaN           False                    1.0
#
#           especialidad       sede      idcx admision
# 0            ortopedia  LEON XIII  109718.0  5466001
# 1             urologia  LEON XIII  109856.0  5466001
# 2            ortopedia  LEON XIII  110056.0  5466001
# 3            ortopedia  LEON XIII  110349.0  5466001
# 4            ortopedia  LEON XIII  110480.0  5466001
# ...                ...        ...       ...      ...
# 1082         ortopedia      PRADO  132416.0  6121284
# 1083         ortopedia      PRADO  132427.0  6121928
# 1084  cirugia plastica      PRADO  132700.0  6129844
# 1085   cirugia general      PRADO  132904.0  6136389
# 1086      dermatologia      PRADO  133370.0  6150985
#
# [1087 rows x 41 columns]

# %%
cx.columns
# Out:
# Index(['unnamed: 0', 'year', 'mes', 'codigo servicio habilitacion',
#        'servicio habilitacion', 'tipo identificacion', 'nrodoc',
#        'fecha nacimiento', 'regimen', 'codigo eps', 'descripcion eps validada',
#        'fecha orden', 'origen orden', 'origen admsion', 'quirofano',
#        'tipo procedimiento', 'fecha preanestesia', 'asa', 'fecha cirugia',
#        'tipo de anestesia', 'fecha recuperacion cx', 'via', 'cod cups',
#        'nombre de procedimiento', 'procedimiento 0256',
#        'cod diagnostico prequirurgico', 'descripcion prequirurgico',
#        'cie 10 tercer caracter', 'descripcion tercer caracter',
#        'capitulo cie10', 'nombre capitulo', 'cod diagnostico postquirurgico',
#        'diagnostico postquirurgico', 'tipo de herida', 'tipo aislamiento',
#        'complicaciones', 'categoria complicacion', 'especialidad', 'sede',
#        'idcx', 'admision'],
#       dtype='object')

# %%
cx.columns= cx.columns.str.lower()

# %%
#Aplicar funciones para homologar a nivel general.
lista = ['mes','sede']
for i in lista:
    cx[i] = cx[i].str.lower() #minuscula
    cx[i] = cx[i].str.strip() #espacios
    cx[i] = cx[i].apply(lambda x: normalize("NFKD", x).encode("ascii", "ignore").decode("ascii") if pd.notnull(x) else x)

# %%
cx1 = cx.groupby(['nrodoc'])[['unnamed: 0']].count().reset_index()
cx1.rename(columns = {'unnamed: 0':'cantidad de cirugias'},inplace=True)
cx1
# Out:
#      nrodoc  cantidad de cirugias
# 0    306221                     1
# 1    306230                     3
# 2    306233                     1
# 3    306259                     1
# 4    306271                     1
# ..      ...                   ...
# 723  314120                     1
# 724  314125                     1
# 725  314172                     1
# 726  314182                     1
# 727  314187                     1
#
# [728 rows x 2 columns]

# %%
# verificar cantidad de cirugias con registro único en cx
cx[(cx['nrodoc'] == 306221)]
# Out:
#      unnamed: 0  year    mes  codigo servicio habilitacion  \
# 678        1532  2022  enero                         217.0
#
#     servicio habilitacion tipo identificacion  nrodoc fecha nacimiento  \
# 678        otras cirugias                  CC  306221       1938-09-09
#
#           regimen  codigo eps  ... cod diagnostico postquirurgico  \
# 678  contributivo      1415.0  ...                           M170
#
#          diagnostico postquirurgico tipo de herida tipo aislamiento  \
# 678  GONARTROSIS PRIMARIA BILATERAL         limpia              NaN
#
#      complicaciones categoria complicacion  \
# 678           False                    3.0
#
#                                especialidad       sede      idcx admision
# 678  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
#
# [1 rows x 41 columns]

# %%
# verificar cantidad de cirugias con registro único en cx
cronicos[(cronicos['nrodoc'] == 306221)]
# Out:
#        unnamed: 0  year         mes fecha diligenciamiento           hora  \
# 10393       23612  2021  SEPTIEMBRE             2021-09-14  10:57:03 a.m.
# 15573       28919  2021   DICIEMBRE             2021-12-20  10:47:00 a.m.
# 21216       34630  2022       MARZO             2022-03-23   8:53:44 a.m.
#
#        atención  ingreso tipo  nrodoc  peso  ...  \
# 10393   5782373  4021570   CC  306221  75.0  ...
# 15573   5902300  4155406   CC  306221  73.0  ...
# 21216   6009224  4267035   CC  306221  74.0  ...
#
#        vo2 - máxima cantidad de oxígeno  índice de fragilidad groningen  \
# 10393                            5.6854                             6.0
# 15573                            5.3935                             4.0
# 21216                            6.0060                             2.0
#
#       calificación (índice de fragilidad)  \
# 10393                              Frágil
# 15573                              Normal
# 21216                              Normal
#
#        tiempo en segundos (apoyo monopodal)  calificación (apoyo monopodal)  \
# 10393                                     0                   Malo - Fragil
# 15573                                     0                   Malo - Fragil
# 21216                                     0                   Malo - Fragil
#
#        tiempo en segundos (recorrer 5 metros)  velocidad (m/s)  \
# 10393                                       9             0.56
# 15573                                       9             0.56
# 21216                                       4             1.25
#
#        calificación velocidad  requiere cita de morbilidad  \
# 10393           Malo - Frágil                           No
# 15573           Malo - Frágil                           No
# 21216               Aceptable                           No
#
#        ambito según el médico
# 10393             Ambulatorio
# 15573             Ambulatorio
# 21216             Ambulatorio
#
# [3 rows x 36 columns]

# %%
dfcx = pd.merge(cx1,cx, on = 'nrodoc',how = 'inner')
dfcx
# Out:
#       nrodoc  cantidad de cirugias  unnamed: 0  year        mes  \
# 0     306221                     1        1532  2022      enero
# 1     306230                     3        1486  2021  diciembre
# 2     306230                     3        1487  2021  diciembre
# 3     306230                     3        1495  2022      enero
# 4     306233                     1        1801  2022       mayo
# ...      ...                   ...         ...   ...        ...
# 1082  314120                     1        1593  2022    febrero
# 1083  314125                     1        1803  2022       mayo
# 1084  314172                     1        1685  2022      marzo
# 1085  314182                     1        1610  2022      marzo
# 1086  314187                     1        1562  2022    febrero
#
#       codigo servicio habilitacion           servicio habilitacion  \
# 0                            217.0                  otras cirugias
# 1                            203.0                 cirugia general
# 2                            203.0                 cirugia general
# 3                            245.0                    neurocirugia
# 4                            207.0              cirugia ortopedica
# ...                            ...                             ...
# 1082                         207.0              cirugia ortopedica
# 1083                         213.0     cirugia plastica y estetica
# 1084                         214.0  cirugia vascular y angiologica
# 1085                         207.0              cirugia ortopedica
# 1086                         214.0  cirugia vascular y angiologica
#
#      tipo identificacion fecha nacimiento       regimen  ...  \
# 0                     CC       1938-09-09  contributivo  ...
# 1                     CC       1940-01-25    subsidiado  ...
# 2                     CC       1940-01-25    subsidiado  ...
# 3                     CC       1940-01-25  contributivo  ...
# 4                     CC       1942-07-22  contributivo  ...
# ...                  ...              ...           ...  ...
# 1082                  CC       1962-04-22  contributivo  ...
# 1083                  CC       1948-09-10  contributivo  ...
# 1084                  CC       1938-01-01  contributivo  ...
# 1085                  CC       1926-12-05  contributivo  ...
# 1086                  CC       1942-07-27  contributivo  ...
#
#       cod diagnostico postquirurgico  \
# 0                               M170
# 1                               K810
# 2                               K810
# 3                               G919
# 4                               S721
# ...                              ...
# 1082                            S525
# 1083                            C443
# 1084                            I702
# 1085                            S721
# 1086                            I771
#
#                              diagnostico postquirurgico tipo de herida  \
# 0                        GONARTROSIS PRIMARIA BILATERAL         limpia
# 1                                    COLECISTITIS AGUDA          sucia
# 2                                    COLECISTITIS AGUDA    contaminada
# 3                           HIDROCEFALO NO ESPECIFICADO    contaminada
# 4                             FRACTURA PERTROCANTERIANA         limpia
# ...                                                 ...            ...
# 1082         FRACTURA DE LA EPIFISIS INFERIOR DEL RADIO         limpia
# 1083  TUMOR MALIGNO DE LA PIEL DE OTRAS PARTES Y DE ...         limpia
# 1084     ATEROSCLEROSIS DE LAS ARTERIAS DE LOS MIEMBROS          sucia
# 1085                          FRACTURA PERTROCANTERIANA         limpia
# 1086                                 ESTRECHEZ ARTERIAL         limpia
#
#      tipo aislamiento complicaciones  categoria complicacion  \
# 0                 NaN          False                     3.0
# 1                 NaN          False                     3.0
# 2                 NaN          False                     3.0
# 3                 NaN          False                     3.0
# 4                 NaN          False                     3.0
# ...               ...            ...                     ...
# 1082              NaN          False                     3.0
# 1083              NaN          False                     2.0
# 1084              NaN          False                     3.0
# 1085              NaN          False                     3.0
# 1086              NaN          False                     3.0
#
#                                 especialidad       sede      idcx admision
# 0     medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 1                             otras cirugias  leon xiii  125132.0  5929611
# 2                            cirugia general  leon xiii  125132.0  5929611
# 3                               neurocirugia  leon xiii  125361.0  5929611
# 4                                  ortopedia  leon xiii  132024.0  6105562
# ...                                      ...        ...       ...      ...
# 1082                               ortopedia  leon xiii  127707.0  5992455
# 1083                        cirugia plastica  leon xiii  132106.0  6080691
# 1084                        cirugia vascular  leon xiii  129503.0  6035935
# 1085                               ortopedia  leon xiii  128140.0  6003330
# 1086                        cirugia vascular  leon xiii  127105.0  5976438
#
# [1087 rows x 42 columns]

# %%
dfcx[(dfcx['nrodoc'] == 306230)]
# Out:
#    nrodoc  cantidad de cirugias  unnamed: 0  year        mes  \
# 1  306230                     3        1486  2021  diciembre
# 2  306230                     3        1487  2021  diciembre
# 3  306230                     3        1495  2022      enero
#
#    codigo servicio habilitacion servicio habilitacion tipo identificacion  \
# 1                         203.0       cirugia general                  CC
# 2                         203.0       cirugia general                  CC
# 3                         245.0          neurocirugia                  CC
#
#   fecha nacimiento       regimen  ...  cod diagnostico postquirurgico  \
# 1       1940-01-25    subsidiado  ...                            K810
# 2       1940-01-25    subsidiado  ...                            K810
# 3       1940-01-25  contributivo  ...                            G919
#
#     diagnostico postquirurgico tipo de herida tipo aislamiento complicaciones  \
# 1           COLECISTITIS AGUDA          sucia              NaN          False
# 2           COLECISTITIS AGUDA    contaminada              NaN          False
# 3  HIDROCEFALO NO ESPECIFICADO    contaminada              NaN          False
#
#    categoria complicacion     especialidad       sede      idcx admision
# 1                     3.0   otras cirugias  leon xiii  125132.0  5929611
# 2                     3.0  cirugia general  leon xiii  125132.0  5929611
# 3                     3.0     neurocirugia  leon xiii  125361.0  5929611
#
# [3 rows x 42 columns]

# %%
dfcx=dfcx.drop_duplicates(subset=['nrodoc'])

# %%
dfcx = dfcx.drop(['unnamed: 0','servicio habilitacion','tipo identificacion','descripcion eps validada','asa','descripcion prequirurgico','nombre de procedimiento',
              'descripcion tercer caracter', 'nombre capitulo','diagnostico postquirurgico'], axis=1)

# eliminados: 'descripcion tercer caracter', 'nombre capitulo','diagnostico postquirurgico'
# no eliminados: cie 10 tercer caracter','capitulo cie10', 'cod diagnostico postquirurgico', 'tipo de herida', 'tipo aislamiento','complicaciones', 'categoria complicacion'
dfcx
# Out:
#       nrodoc  cantidad de cirugias  year        mes  \
# 0     306221                     1  2022      enero
# 1     306230                     3  2021  diciembre
# 4     306233                     1  2022       mayo
# 5     306259                     1  2021  noviembre
# 6     306271                     1  2021      julio
# ...      ...                   ...   ...        ...
# 1082  314120                     1  2022    febrero
# 1083  314125                     1  2022       mayo
# 1084  314172                     1  2022      marzo
# 1085  314182                     1  2022      marzo
# 1086  314187                     1  2022    febrero
#
#       codigo servicio habilitacion fecha nacimiento       regimen  codigo eps  \
# 0                            217.0       1938-09-09  contributivo      1415.0
# 1                            203.0       1940-01-25    subsidiado      1415.0
# 4                            207.0       1942-07-22  contributivo      2889.0
# 5                            207.0       1932-05-10    subsidiado      1415.0
# 6                            202.0       1944-04-22    subsidiado      1415.0
# ...                            ...              ...           ...         ...
# 1082                         207.0       1962-04-22  contributivo      1415.0
# 1083                         213.0       1948-09-10  contributivo      2889.0
# 1084                         214.0       1938-01-01  contributivo      1415.0
# 1085                         207.0       1926-12-05  contributivo      2889.0
# 1086                         214.0       1942-07-27  contributivo      2891.0
#
#      fecha orden       origen orden  ... capitulo cie10  \
# 0     2021-12-15        ambulatorio  ...        M00-M99
# 1     2021-12-28        ambulatorio  ...        K00-K93
# 4     2022-05-19        ambulatorio  ...        S00-T98
# 5     2021-11-18    hospitalizacion  ...        S00-T98
# 6     2021-07-21        ambulatorio  ...        I00-I99
# ...          ...                ...  ...            ...
# 1082  2022-02-18        ambulatorio  ...        S00-T98
# 1083  2022-05-04        ambulatorio  ...        C00-D48
# 1084  2022-03-26    hospitalizacion  ...        I00-I99
# 1085  2022-03-01  urgencias adultos  ...        S00-T98
# 1086  2022-02-07        ambulatorio  ...        I00-I99
#
#       cod diagnostico postquirurgico tipo de herida tipo aislamiento  \
# 0                               M170         limpia              NaN
# 1                               K810          sucia              NaN
# 4                               S721         limpia              NaN
# 5                               S721         limpia              NaN
# 6                               I255         limpia              NaN
# ...                              ...            ...              ...
# 1082                            S525         limpia              NaN
# 1083                            C443         limpia              NaN
# 1084                            I702          sucia              NaN
# 1085                            S721         limpia              NaN
# 1086                            I771         limpia              NaN
#
#      complicaciones categoria complicacion  \
# 0             False                    3.0
# 1             False                    3.0
# 4             False                    3.0
# 5             False                    3.0
# 6             False                    3.0
# ...             ...                    ...
# 1082          False                    3.0
# 1083          False                    2.0
# 1084          False                    3.0
# 1085          False                    3.0
# 1086          False                    3.0
#
#                                 especialidad       sede      idcx  admision
# 0     medicina del dolor y cuidado paliativo  leon xiii  126470.0   5919903
# 1                             otras cirugias  leon xiii  125132.0   5929611
# 4                                  ortopedia  leon xiii  132024.0   6105562
# 5                                  ortopedia  leon xiii  123263.0   5881701
# 6                             otras cirugias  leon xiii  117503.0   5724777
# ...                                      ...        ...       ...       ...
# 1082                               ortopedia  leon xiii  127707.0   5992455
# 1083                        cirugia plastica  leon xiii  132106.0   6080691
# 1084                        cirugia vascular  leon xiii  129503.0   6035935
# 1085                               ortopedia  leon xiii  128140.0   6003330
# 1086                        cirugia vascular  leon xiii  127105.0   5976438
#
# [728 rows x 32 columns]

# %%
dfcx.shape
# Out:
# (728, 32)

# %%
dfcx.isnull().sum()
# Out:
# nrodoc                              0
# cantidad de cirugias                0
# year                                0
# mes                                 0
# codigo servicio habilitacion        6
# fecha nacimiento                    0
# regimen                             0
# codigo eps                          0
# fecha orden                         0
# origen orden                        0
# origen admsion                      0
# quirofano                           0
# tipo procedimiento                  0
# fecha preanestesia                104
# fecha cirugia                       0
# tipo de anestesia                 101
# fecha recuperacion cx              34
# via                                 0
# cod cups                            0
# procedimiento 0256                  0
# cod diagnostico prequirurgico       0
# cie 10 tercer caracter              0
# capitulo cie10                      0
# cod diagnostico postquirurgico      0
# tipo de herida                      0
# tipo aislamiento                  716
# complicaciones                     31
# categoria complicacion              0
# especialidad                        0
# sede                                0
# idcx                                0
# admision                            0
# dtype: int64

# %%
dfcx2 = pd.merge(dfcx,usuarios2, on = 'nrodoc', how = 'inner')
dfcx2
# Out:
#        nrodoc  cantidad de cirugias  year    mes_x  \
# 0      306221                     1  2022    enero
# 1      306221                     1  2022    enero
# 2      306221                     1  2022    enero
# 3      306221                     1  2022    enero
# 4      306221                     1  2022    enero
# ...       ...                   ...   ...      ...
# 11779  314187                     1  2022  febrero
# 11780  314187                     1  2022  febrero
# 11781  314187                     1  2022  febrero
# 11782  314187                     1  2022  febrero
# 11783  314187                     1  2022  febrero
#
#        codigo servicio habilitacion fecha nacimiento       regimen  \
# 0                             217.0       1938-09-09  contributivo
# 1                             217.0       1938-09-09  contributivo
# 2                             217.0       1938-09-09  contributivo
# 3                             217.0       1938-09-09  contributivo
# 4                             217.0       1938-09-09  contributivo
# ...                             ...              ...           ...
# 11779                         214.0       1942-07-27  contributivo
# 11780                         214.0       1942-07-27  contributivo
# 11781                         214.0       1942-07-27  contributivo
# 11782                         214.0       1942-07-27  contributivo
# 11783                         214.0       1942-07-27  contributivo
#
#        codigo eps fecha orden origen orden  ...  \
# 0          1415.0  2021-12-15  ambulatorio  ...
# 1          1415.0  2021-12-15  ambulatorio  ...
# 2          1415.0  2021-12-15  ambulatorio  ...
# 3          1415.0  2021-12-15  ambulatorio  ...
# 4          1415.0  2021-12-15  ambulatorio  ...
# ...           ...         ...          ...  ...
# 11779      2891.0  2022-02-07  ambulatorio  ...
# 11780      2891.0  2022-02-07  ambulatorio  ...
# 11781      2891.0  2022-02-07  ambulatorio  ...
# 11782      2891.0  2022-02-07  ambulatorio  ...
# 11783      2891.0  2022-02-07  ambulatorio  ...
#
#                                  especialidad       sede      idcx admision  \
# 0      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 1      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 2      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 3      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 4      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# ...                                       ...        ...       ...      ...
# 11779                        cirugia vascular  leon xiii  127105.0  5976438
# 11780                        cirugia vascular  leon xiii  127105.0  5976438
# 11781                        cirugia vascular  leon xiii  127105.0  5976438
# 11782                        cirugia vascular  leon xiii  127105.0  5976438
# 11783                        cirugia vascular  leon xiii  127105.0  5976438
#
#       cantidad de registros en el sistema    mes_y   año sexo  edad  municipio
# 0                                       3    enero  2021    f    82   medellin
# 1                                       3  febrero  2021    f    82   medellin
# 2                                       3    marzo  2021    f    82   medellin
# 3                                       3    abril  2021    f    82   medellin
# 4                                       3     mayo  2021    f    82   medellin
# ...                                   ...      ...   ...  ...   ...        ...
# 11779                                   3  febrero  2022    f    79   medellin
# 11780                                   3    marzo  2022    f    79   medellin
# 11781                                   3    abril  2022    f    79   medellin
# 11782                                   3     mayo  2022    f    79   medellin
# 11783                                   3    junio  2022    f    79   medellin
#
# [11784 rows x 38 columns]

# %%
dfcx2[(dfcx2['nrodoc'] == 306221)]
# Out:
#     nrodoc  cantidad de cirugias  year  mes_x  codigo servicio habilitacion  \
# 0   306221                     1  2022  enero                         217.0
# 1   306221                     1  2022  enero                         217.0
# 2   306221                     1  2022  enero                         217.0
# 3   306221                     1  2022  enero                         217.0
# 4   306221                     1  2022  enero                         217.0
# 5   306221                     1  2022  enero                         217.0
# 6   306221                     1  2022  enero                         217.0
# 7   306221                     1  2022  enero                         217.0
# 8   306221                     1  2022  enero                         217.0
# 9   306221                     1  2022  enero                         217.0
# 10  306221                     1  2022  enero                         217.0
# 11  306221                     1  2022  enero                         217.0
# 12  306221                     1  2022  enero                         217.0
# 13  306221                     1  2022  enero                         217.0
# 14  306221                     1  2022  enero                         217.0
# 15  306221                     1  2022  enero                         217.0
# 16  306221                     1  2022  enero                         217.0
# 17  306221                     1  2022  enero                         217.0
#
#    fecha nacimiento       regimen  codigo eps fecha orden origen orden  ...  \
# 0        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 1        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 2        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 3        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 4        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 5        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 6        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 7        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 8        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 9        1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 10       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 11       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 12       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 13       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 14       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 15       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 16       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
# 17       1938-09-09  contributivo      1415.0  2021-12-15  ambulatorio  ...
#
#                               especialidad       sede      idcx admision  \
# 0   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 1   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 2   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 3   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 4   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 5   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 6   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 7   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 8   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 9   medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 10  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 11  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 12  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 13  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 14  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 15  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 16  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 17  medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
#
#    cantidad de registros en el sistema       mes_y   año sexo  edad  municipio
# 0                                    3       enero  2021    f    82   medellin
# 1                                    3     febrero  2021    f    82   medellin
# 2                                    3       marzo  2021    f    82   medellin
# 3                                    3       abril  2021    f    82   medellin
# 4                                    3        mayo  2021    f    82   medellin
# 5                                    3       junio  2021    f    82   medellin
# 6                                    3       julio  2021    f    82   medellin
# 7                                    3      agosto  2021    f    82   medellin
# 8                                    3  septiembre  2021    f    83   medellin
# 9                                    3     octubre  2021    f    83   medellin
# 10                                   3   noviembre  2021    f    83   medellin
# 11                                   3   diciembre  2021    f    83   medellin
# 12                                   3       enero  2022    f    83   medellin
# 13                                   3     febrero  2022    f    83   medellin
# 14                                   3       marzo  2022    f    83   medellin
# 15                                   3       abril  2022    f    83   medellin
# 16                                   3        mayo  2022    f    83   medellin
# 17                                   3       junio  2022    f    83   medellin
#
# [18 rows x 38 columns]

# %%
dfcx2=dfcx2.drop_duplicates(subset=['nrodoc'])
dfcx2
# Out:
#        nrodoc  cantidad de cirugias  year      mes_x  \
# 0      306221                     1  2022      enero
# 18     306230                     3  2021  diciembre
# 31     306233                     1  2022       mayo
# 49     306259                     1  2021  noviembre
# 67     306271                     1  2021      julio
# ...       ...                   ...   ...        ...
# 11757  314120                     1  2022    febrero
# 11763  314125                     1  2022       mayo
# 11769  314172                     1  2022      marzo
# 11774  314182                     1  2022      marzo
# 11779  314187                     1  2022    febrero
#
#        codigo servicio habilitacion fecha nacimiento       regimen  \
# 0                             217.0       1938-09-09  contributivo
# 18                            203.0       1940-01-25    subsidiado
# 31                            207.0       1942-07-22  contributivo
# 49                            207.0       1932-05-10    subsidiado
# 67                            202.0       1944-04-22    subsidiado
# ...                             ...              ...           ...
# 11757                         207.0       1962-04-22  contributivo
# 11763                         213.0       1948-09-10  contributivo
# 11769                         214.0       1938-01-01  contributivo
# 11774                         207.0       1926-12-05  contributivo
# 11779                         214.0       1942-07-27  contributivo
#
#        codigo eps fecha orden       origen orden  ...  \
# 0          1415.0  2021-12-15        ambulatorio  ...
# 18         1415.0  2021-12-28        ambulatorio  ...
# 31         2889.0  2022-05-19        ambulatorio  ...
# 49         1415.0  2021-11-18    hospitalizacion  ...
# 67         1415.0  2021-07-21        ambulatorio  ...
# ...           ...         ...                ...  ...
# 11757      1415.0  2022-02-18        ambulatorio  ...
# 11763      2889.0  2022-05-04        ambulatorio  ...
# 11769      1415.0  2022-03-26    hospitalizacion  ...
# 11774      2889.0  2022-03-01  urgencias adultos  ...
# 11779      2891.0  2022-02-07        ambulatorio  ...
#
#                                  especialidad       sede      idcx admision  \
# 0      medicina del dolor y cuidado paliativo  leon xiii  126470.0  5919903
# 18                             otras cirugias  leon xiii  125132.0  5929611
# 31                                  ortopedia  leon xiii  132024.0  6105562
# 49                                  ortopedia  leon xiii  123263.0  5881701
# 67                             otras cirugias  leon xiii  117503.0  5724777
# ...                                       ...        ...       ...      ...
# 11757                               ortopedia  leon xiii  127707.0  5992455
# 11763                        cirugia plastica  leon xiii  132106.0  6080691
# 11769                        cirugia vascular  leon xiii  129503.0  6035935
# 11774                               ortopedia  leon xiii  128140.0  6003330
# 11779                        cirugia vascular  leon xiii  127105.0  5976438
#
#       cantidad de registros en el sistema    mes_y   año sexo  edad  municipio
# 0                                       3    enero  2021    f    82   medellin
# 18                                      4    enero  2021    f    81     itagui
# 31                                     10    enero  2021    f    78      bello
# 49                                      4    enero  2021    f    88   medellin
# 67                                      5    enero  2021    f    76   medellin
# ...                                   ...      ...   ...  ...   ...        ...
# 11757                                   2    enero  2022    m    59   medellin
# 11763                                   2    enero  2022    f    73   medellin
# 11769                                   3  febrero  2022    m    84   medellin
# 11774                                   2  febrero  2022    f    95   medellin
# 11779                                   3  febrero  2022    f    79   medellin
#
# [705 rows x 38 columns]

# %%
dfcx2[(dfcx2['nrodoc'] == 306230)]
# Out:
#     nrodoc  cantidad de cirugias  year      mes_x  \
# 18  306230                     3  2021  diciembre
#
#     codigo servicio habilitacion fecha nacimiento     regimen  codigo eps  \
# 18                         203.0       1940-01-25  subsidiado      1415.0
#
#    fecha orden origen orden  ...    especialidad       sede      idcx  \
# 18  2021-12-28  ambulatorio  ...  otras cirugias  leon xiii  125132.0
#
#    admision cantidad de registros en el sistema  mes_y   año sexo  edad  \
# 18  5929611                                   4  enero  2021    f    81
#
#     municipio
# 18     itagui
#
# [1 rows x 38 columns]

# %%
dfcx3 = pd.merge(dfcx2,cronicos2, on = 'nrodoc', how = 'inner')
dfcx3
# Out:
#      nrodoc  cantidad de cirugias  year_x      mes_x  \
# 0    306221                     1    2022      enero
# 1    306230                     3    2021  diciembre
# 2    306233                     1    2022       mayo
# 3    306259                     1    2021  noviembre
# 4    306271                     1    2021      julio
# ..      ...                   ...     ...        ...
# 700  314120                     1    2022    febrero
# 701  314125                     1    2022       mayo
# 702  314172                     1    2022      marzo
# 703  314182                     1    2022      marzo
# 704  314187                     1    2022    febrero
#
#      codigo servicio habilitacion fecha nacimiento       regimen  codigo eps  \
# 0                           217.0       1938-09-09  contributivo      1415.0
# 1                           203.0       1940-01-25    subsidiado      1415.0
# 2                           207.0       1942-07-22  contributivo      2889.0
# 3                           207.0       1932-05-10    subsidiado      1415.0
# 4                           202.0       1944-04-22    subsidiado      1415.0
# ..                            ...              ...           ...         ...
# 700                         207.0       1962-04-22  contributivo      1415.0
# 701                         213.0       1948-09-10  contributivo      2889.0
# 702                         214.0       1938-01-01  contributivo      1415.0
# 703                         207.0       1926-12-05  contributivo      2889.0
# 704                         214.0       1942-07-27  contributivo      2891.0
#
#     fecha orden       origen orden  ... auto-calificacion nivel de ejercicio  \
# 0    2021-12-15        ambulatorio  ...                                    1
# 1    2021-12-28        ambulatorio  ...                                    1
# 2    2022-05-19        ambulatorio  ...                                    1
# 3    2021-11-18    hospitalizacion  ...                                    1
# 4    2021-07-21        ambulatorio  ...                                    1
# ..          ...                ...  ...                                  ...
# 700  2022-02-18        ambulatorio  ...                                    1
# 701  2022-05-04        ambulatorio  ...                                    1
# 702  2022-03-26    hospitalizacion  ...                                    1
# 703  2022-03-01  urgencias adultos  ...                                    1
# 704  2022-02-07        ambulatorio  ...                                    1
#
#      constantes mets -índice metabólico vo2 - máxima cantidad de oxígeno  \
# 0           0.0                  1.6244                           5.6854
# 1           0.0                  3.7469                          13.1141
# 2           0.0                  4.8987                          17.1455
# 3           0.0                  2.1397                           7.4889
# 4           0.0                  2.7632                           9.6712
# ..          ...                     ...                              ...
# 700         0.0                  6.7003                          23.4511
# 701         0.0                  2.2748                           7.9618
# 702         0.0                  4.7875                          16.7563
# 703         0.0                  2.4252                           8.4882
# 704         0.0                  2.9036                          10.1626
#
#     índice de fragilidad groningen tiempo en segundos (apoyo monopodal)  \
# 0                              6.0                                    0
# 1                              5.0                                    0
# 2                              9.0                                    0
# 3                              4.0                                    3
# 4                              1.0                                    3
# ..                             ...                                  ...
# 700                            3.0                                    4
# 701                            3.0                                    0
# 702                           10.0                                    0
# 703                            7.0                                    0
# 704                            8.0                                    6
#
#     tiempo en segundos (recorrer 5 metros) velocidad (m/s)  \
# 0                                        9            0.56
# 1                                        9            0.56
# 2                                        0            0.00
# 3                                        3            1.67
# 4                                        7            0.71
# ..                                     ...             ...
# 700                                      8            0.63
# 701                                      5            1.00
# 702                                      0            0.00
# 703                                      0            0.00
# 704                                      6            0.83
#
#      requiere cita de morbilidad  ambito según el médico
# 0                             No             Ambulatorio
# 1                             No             Ambulatorio
# 2                             Si            Domiciliario
# 3                             No             Ambulatorio
# 4                             No             Ambulatorio
# ..                           ...                     ...
# 700                           No             Ambulatorio
# 701                           No             Ambulatorio
# 702                           Si            Domiciliario
# 703                           No            Domiciliario
# 704                           Si            Domiciliario
#
# [705 rows x 68 columns]

# %%
dfcx3=dfcx3.drop_duplicates(subset=['nrodoc'])
dfcx3
# Out:
#      nrodoc  cantidad de cirugias  year_x      mes_x  \
# 0    306221                     1    2022      enero
# 1    306230                     3    2021  diciembre
# 2    306233                     1    2022       mayo
# 3    306259                     1    2021  noviembre
# 4    306271                     1    2021      julio
# ..      ...                   ...     ...        ...
# 700  314120                     1    2022    febrero
# 701  314125                     1    2022       mayo
# 702  314172                     1    2022      marzo
# 703  314182                     1    2022      marzo
# 704  314187                     1    2022    febrero
#
#      codigo servicio habilitacion fecha nacimiento       regimen  codigo eps  \
# 0                           217.0       1938-09-09  contributivo      1415.0
# 1                           203.0       1940-01-25    subsidiado      1415.0
# 2                           207.0       1942-07-22  contributivo      2889.0
# 3                           207.0       1932-05-10    subsidiado      1415.0
# 4                           202.0       1944-04-22    subsidiado      1415.0
# ..                            ...              ...           ...         ...
# 700                         207.0       1962-04-22  contributivo      1415.0
# 701                         213.0       1948-09-10  contributivo      2889.0
# 702                         214.0       1938-01-01  contributivo      1415.0
# 703                         207.0       1926-12-05  contributivo      2889.0
# 704                         214.0       1942-07-27  contributivo      2891.0
#
#     fecha orden       origen orden  ... auto-calificacion nivel de ejercicio  \
# 0    2021-12-15        ambulatorio  ...                                    1
# 1    2021-12-28        ambulatorio  ...                                    1
# 2    2022-05-19        ambulatorio  ...                                    1
# 3    2021-11-18    hospitalizacion  ...                                    1
# 4    2021-07-21        ambulatorio  ...                                    1
# ..          ...                ...  ...                                  ...
# 700  2022-02-18        ambulatorio  ...                                    1
# 701  2022-05-04        ambulatorio  ...                                    1
# 702  2022-03-26    hospitalizacion  ...                                    1
# 703  2022-03-01  urgencias adultos  ...                                    1
# 704  2022-02-07        ambulatorio  ...                                    1
#
#      constantes mets -índice metabólico vo2 - máxima cantidad de oxígeno  \
# 0           0.0                  1.6244                           5.6854
# 1           0.0                  3.7469                          13.1141
# 2           0.0                  4.8987                          17.1455
# 3           0.0                  2.1397                           7.4889
# 4           0.0                  2.7632                           9.6712
# ..          ...                     ...                              ...
# 700         0.0                  6.7003                          23.4511
# 701         0.0                  2.2748                           7.9618
# 702         0.0                  4.7875                          16.7563
# 703         0.0                  2.4252                           8.4882
# 704         0.0                  2.9036                          10.1626
#
#     índice de fragilidad groningen tiempo en segundos (apoyo monopodal)  \
# 0                              6.0                                    0
# 1                              5.0                                    0
# 2                              9.0                                    0
# 3                              4.0                                    3
# 4                              1.0                                    3
# ..                             ...                                  ...
# 700                            3.0                                    4
# 701                            3.0                                    0
# 702                           10.0                                    0
# 703                            7.0                                    0
# 704                            8.0                                    6
#
#     tiempo en segundos (recorrer 5 metros) velocidad (m/s)  \
# 0                                        9            0.56
# 1                                        9            0.56
# 2                                        0            0.00
# 3                                        3            1.67
# 4                                        7            0.71
# ..                                     ...             ...
# 700                                      8            0.63
# 701                                      5            1.00
# 702                                      0            0.00
# 703                                      0            0.00
# 704                                      6            0.83
#
#      requiere cita de morbilidad  ambito según el médico
# 0                             No             Ambulatorio
# 1                             No             Ambulatorio
# 2                             Si            Domiciliario
# 3                             No             Ambulatorio
# 4                             No             Ambulatorio
# ..                           ...                     ...
# 700                           No             Ambulatorio
# 701                           No             Ambulatorio
# 702                           Si            Domiciliario
# 703                           No            Domiciliario
# 704                           Si            Domiciliario
#
# [705 rows x 68 columns]

# %%
dfcx3 = dfcx3.drop('fecha preanestesia', axis=1)
dfcx3 = dfcx3.ffill()

# %%
dfcx3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Data columns (total 67 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   nrodoc                                  705 non-null    int64
#  1   cantidad de cirugias                    705 non-null    int64
#  2   year_x                                  705 non-null    int64
#  3   mes_x                                   705 non-null    object
#  4   codigo servicio habilitacion            705 non-null    float64
#  5   fecha nacimiento                        705 non-null    object
#  6   regimen                                 705 non-null    object
#  7   codigo eps                              705 non-null    float64
#  8   fecha orden                             705 non-null    object
#  9   origen orden                            705 non-null    object
#  10  origen admsion                          705 non-null    object
#  11  quirofano                               705 non-null    int64
#  12  tipo procedimiento                      705 non-null    object
#  13  fecha cirugia                           705 non-null    object
#  14  tipo de anestesia                       705 non-null    object
#  15  fecha recuperacion cx                   705 non-null    object
#  16  via                                     705 non-null    object
#  17  cod cups                                705 non-null    int64
#  18  procedimiento 0256                      705 non-null    float64
#  19  cod diagnostico prequirurgico           705 non-null    object
#  20  cie 10 tercer caracter                  705 non-null    object
#  21  capitulo cie10                          705 non-null    object
#  22  cod diagnostico postquirurgico          705 non-null    object
#  23  tipo de herida                          705 non-null    object
#  24  tipo aislamiento                        700 non-null    object
#  25  complicaciones                          705 non-null    bool
#  26  categoria complicacion                  705 non-null    float64
#  27  especialidad                            705 non-null    object
#  28  sede                                    705 non-null    object
#  29  idcx                                    705 non-null    float64
#  30  admision                                705 non-null    int64
#  31  cantidad de registros en el sistema     705 non-null    int64
#  32  mes_y                                   705 non-null    object
#  33  año                                     705 non-null    int64
#  34  sexo                                    705 non-null    object
#  35  edad                                    705 non-null    int64
#  36  municipio                               705 non-null    object
#  37  cantidad de registros en cronicos       705 non-null    int64
#  38  year_y                                  705 non-null    int64
#  39  mes                                     705 non-null    object
#  40  fecha diligenciamiento                  705 non-null    object
#  41  hora                                    705 non-null    object
#  42  atención                                705 non-null    int64
#  43  ingreso                                 705 non-null    int64
#  44  peso                                    705 non-null    float64
#  45  talla                                   705 non-null    float64
#  46  imc                                     705 non-null    float64
#  47  saturación de oxígeno (%)               705 non-null    float64
#  48  perímetro muslo                         705 non-null    float64
#  49  perímetro cintura                       705 non-null    float64
#  50  pliegue triceps                         705 non-null    float64
#  51  pliegue abdomen                         705 non-null    float64
#  52  pliegue muslo                           705 non-null    float64
#  53  sumatoria pliegues                      705 non-null    float64
#  54  presión arterial sistólica              705 non-null    int64
#  55  presión arterial diastólica             705 non-null    int64
#  56  frecuencia cardíaca en reposo           705 non-null    int64
#  57  auto-calificacion nivel de ejercicio    705 non-null    int64
#  58  constantes                              705 non-null    float64
#  59  mets -índice metabólico                 705 non-null    float64
#  60  vo2 - máxima cantidad de oxígeno        705 non-null    float64
#  61  índice de fragilidad groningen          705 non-null    float64
#  62  tiempo en segundos (apoyo monopodal)    705 non-null    int64
#  63  tiempo en segundos (recorrer 5 metros)  705 non-null    int64
#  64  velocidad (m/s)                         705 non-null    float64
#  65  requiere cita de morbilidad             705 non-null    object
#  66  ambito según el médico                  705 non-null    object
# dtypes: bool(1), float64(20), int64(19), object(27)
# memory usage: 369.7+ KB

# %% [markdown]
# **Selección de las variables y modelo**

# %%
# Eliminar variables
dfcx3 = dfcx3.drop(['year_x', 'mes_x','fecha recuperacion cx','nrodoc','fecha nacimiento','tipo procedimiento', 'mes_y', 'año',
                   'year_y', 'mes','fecha diligenciamiento', 'hora'],axis=1)

# %%
dfcx3['fecha cirugia'] = pd.to_datetime(dfcx3['fecha cirugia'])

# %%
dfcx3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   cantidad de cirugias                    705 non-null    int64
#  1   codigo servicio habilitacion            705 non-null    float64
#  2   regimen                                 705 non-null    object
#  3   codigo eps                              705 non-null    float64
#  4   fecha orden                             705 non-null    object
#  5   origen orden                            705 non-null    object
#  6   origen admsion                          705 non-null    object
#  7   quirofano                               705 non-null    int64
#  8   fecha cirugia                           705 non-null    datetime64[ns]
#  9   tipo de anestesia                       705 non-null    object
#  10  via                                     705 non-null    object
#  11  cod cups                                705 non-null    int64
#  12  procedimiento 0256                      705 non-null    float64
#  13  cod diagnostico prequirurgico           705 non-null    object
#  14  cie 10 tercer caracter                  705 non-null    object
#  15  capitulo cie10                          705 non-null    object
#  16  cod diagnostico postquirurgico          705 non-null    object
#  17  tipo de herida                          705 non-null    object
#  18  tipo aislamiento                        700 non-null    object
#  19  complicaciones                          705 non-null    bool
#  20  categoria complicacion                  705 non-null    float64
#  21  especialidad                            705 non-null    object
#  22  sede                                    705 non-null    object
#  23  idcx                                    705 non-null    float64
#  24  admision                                705 non-null    int64
#  25  cantidad de registros en el sistema     705 non-null    int64
#  26  sexo                                    705 non-null    object
#  27  edad                                    705 non-null    int64
#  28  municipio                               705 non-null    object
#  29  cantidad de registros en cronicos       705 non-null    int64
#  30  atención                                705 non-null    int64
#  31  ingreso                                 705 non-null    int64
#  32  peso                                    705 non-null    float64
#  33  talla                                   705 non-null    float64
#  34  imc                                     705 non-null    float64
#  35  saturación de oxígeno (%)               705 non-null    float64
#  36  perímetro muslo                         705 non-null    float64
#  37  perímetro cintura                       705 non-null    float64
#  38  pliegue triceps                         705 non-null    float64
#  39  pliegue abdomen                         705 non-null    float64
#  40  pliegue muslo                           705 non-null    float64
#  41  sumatoria pliegues                      705 non-null    float64
#  42  presión arterial sistólica              705 non-null    int64
#  43  presión arterial diastólica             705 non-null    int64
#  44  frecuencia cardíaca en reposo           705 non-null    int64
#  45  auto-calificacion nivel de ejercicio    705 non-null    int64
#  46  constantes                              705 non-null    float64
#  47  mets -índice metabólico                 705 non-null    float64
#  48  vo2 - máxima cantidad de oxígeno        705 non-null    float64
#  49  índice de fragilidad groningen          705 non-null    float64
#  50  tiempo en segundos (apoyo monopodal)    705 non-null    int64
#  51  tiempo en segundos (recorrer 5 metros)  705 non-null    int64
#  52  velocidad (m/s)                         705 non-null    float64
#  53  requiere cita de morbilidad             705 non-null    object
#  54  ambito según el médico                  705 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(20), int64(15), object(18)
# memory usage: 303.6+ KB

# %%
dfcx3.columns
# Out:
# Index(['cantidad de cirugias', 'codigo servicio habilitacion', 'regimen',
#        'codigo eps', 'fecha orden', 'origen orden', 'origen admsion',
#        'quirofano', 'fecha cirugia', 'tipo de anestesia', 'via', 'cod cups',
#        'procedimiento 0256', 'cod diagnostico prequirurgico',
#        'cie 10 tercer caracter', 'capitulo cie10',
#        'cod diagnostico postquirurgico', 'tipo de herida', 'tipo aislamiento',
#        'complicaciones', 'categoria complicacion', 'especialidad', 'sede',
#        'idcx', 'admision', 'cantidad de registros en el sistema', 'sexo',
#        'edad', 'municipio', 'cantidad de registros en cronicos', 'atención',
#        'ingreso', 'peso', 'talla', 'imc', 'saturación de oxígeno (%)',
#        'perímetro muslo', 'perímetro cintura', 'pliegue triceps',
#        'pliegue abdomen', 'pliegue muslo', 'sumatoria pliegues',
#        'presión arterial sistólica', 'presión arterial diastólica',
#        'frecuencia cardíaca en reposo', 'auto-calificacion nivel de ejercicio',
#        'constantes', 'mets -índice metabólico',
#        'vo2 - máxima cantidad de oxígeno', 'índice de fragilidad groningen',
#        'tiempo en segundos (apoyo monopodal)',
#        'tiempo en segundos (recorrer 5 metros)', 'velocidad (m/s)',
#        'requiere cita de morbilidad', 'ambito según el médico'],
#       dtype='object')

# %%
dfcx3['mes'] = dfcx3['fecha cirugia'].dt.month

# %%
dfcx3_dummies = pd.get_dummies(dfcx3,columns=['regimen','origen orden','origen admsion','tipo de anestesia', 'via',
                                              'cod diagnostico prequirurgico','cie 10 tercer caracter', 'capitulo cie10','cod diagnostico postquirurgico',
                                              'tipo de herida', 'tipo aislamiento','especialidad', 'sede','sexo','requiere cita de morbilidad', 'ambito según el médico'])
dfcx3_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Columns: 739 entries, cantidad de cirugias to ambito según el médico_Domiciliario
# dtypes: bool(1), datetime64[ns](1), float64(20), int64(16), object(2), uint8(699)
# memory usage: 702.2+ KB

# %%
dfcx3_dummies.shape
# Out:
# (705, 739)

# %%
# Crear matriz de features y target 
X=dfcx3_dummies.loc[:,~dfcx3_dummies.columns.isin(['cantidad de cirugias', 'fecha cirugia','fecha orden','municipio'])]
y=dfcx3_dummies['cantidad de cirugias']
y = y.astype('float64')

# %%
#importar paquetes
from sklearn import linear_model ## para regresión lineal
from sklearn import tree ###para ajustar arboles de decisión
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor ##Ensamble con bagging
from sklearn.ensemble import GradientBoostingRegressor ###Ensamble boosting
from sklearn.feature_selection import SelectFromModel

# %%
#modelos candidatos
m_lreg = linear_model.LinearRegression()
m_rtree=tree.DecisionTreeRegressor()
m_rf= RandomForestRegressor()
m_gbt=GradientBoostingRegressor()

# %%
modelos=list([m_lreg,m_rtree, m_rf, m_gbt])

# %%
#Se crea una función para determinar que variables se van a elegir
def sel_variables(modelos,X,y, SelectFromModel,np,threshold):
    
    var_names_ac=np.array([])
    for modelo in modelos:
        #modelo=modelos[i]
        modelo.fit(X,y)
        sel = SelectFromModel(modelo, prefit=True,threshold=threshold)
        var_names= sel.get_feature_names_out(modelo.feature_names_in_)
        var_names_ac=np.append(var_names_ac, var_names)
        var_names_ac=np.unique(var_names_ac)
    
    return var_names_ac

# %%
#Variables seleccionadas
var_names = sel_variables( modelos, X, y, SelectFromModel, np, threshold="3*mean")
var_names.shape
# Out:
# (114,)

# %%
var_names
# Out:
# array(['admision', 'atención', 'cantidad de registros en cronicos',
#        'cantidad de registros en el sistema', 'capitulo cie10_E00-E90',
#        'capitulo cie10_I00-I99', 'capitulo cie10_K00-K93',
#        'capitulo cie10_V01-Y98', 'cie 10 tercer caracter_E10',
#        'cie 10 tercer caracter_E11', 'cie 10 tercer caracter_E13',
#        'cie 10 tercer caracter_E21', 'cie 10 tercer caracter_E88',
#        'cie 10 tercer caracter_I71', 'cie 10 tercer caracter_K00',
#        'cie 10 tercer caracter_K04', 'cie 10 tercer caracter_K05',
#        'cie 10 tercer caracter_K11', 'cie 10 tercer caracter_K40',
#        'cie 10 tercer caracter_K43', 'cie 10 tercer caracter_K64',
#        'cie 10 tercer caracter_K65', 'cie 10 tercer caracter_K80',
#        'cie 10 tercer caracter_K82', 'cie 10 tercer caracter_L03',
#        'cie 10 tercer caracter_M00', 'cie 10 tercer caracter_M50',
#        'cie 10 tercer caracter_M75', 'cie 10 tercer caracter_M86',
#        'cie 10 tercer caracter_N84', 'cie 10 tercer caracter_R06',
#        'cie 10 tercer caracter_Y83', 'cod cups',
#        'cod diagnostico postquirurgico_C187',
#        'cod diagnostico postquirurgico_D179',
#        'cod diagnostico postquirurgico_D250',
#        'cod diagnostico postquirurgico_E135',
#        'cod diagnostico postquirurgico_E881',
#        'cod diagnostico postquirurgico_I714',
#        'cod diagnostico postquirurgico_K002',
#        'cod diagnostico postquirurgico_K044',
#        'cod diagnostico postquirurgico_K051',
#        'cod diagnostico postquirurgico_K053',
#        'cod diagnostico postquirurgico_K432',
#        'cod diagnostico postquirurgico_K801',
#        'cod diagnostico postquirurgico_K810',
#        'cod diagnostico postquirurgico_K822',
#        'cod diagnostico postquirurgico_L024',
#        'cod diagnostico postquirurgico_L039',
#        'cod diagnostico postquirurgico_M500',
#        'cod diagnostico postquirurgico_M866',
#        'cod diagnostico postquirurgico_N47X',
#        'cod diagnostico postquirurgico_T818',
#        'cod diagnostico postquirurgico_T845',
#        'cod diagnostico postquirurgico_Y838',
#        'cod diagnostico prequirurgico_C187',
#        'cod diagnostico prequirurgico_E135',
#        'cod diagnostico prequirurgico_E881',
#        'cod diagnostico prequirurgico_I714',
#        'cod diagnostico prequirurgico_K002',
#        'cod diagnostico prequirurgico_K044',
#        'cod diagnostico prequirurgico_K051',
#        'cod diagnostico prequirurgico_K053',
#        'cod diagnostico prequirurgico_K118',
#        'cod diagnostico prequirurgico_K650',
#        'cod diagnostico prequirurgico_K801',
#        'cod diagnostico prequirurgico_K822',
#        'cod diagnostico prequirurgico_L024',
#        'cod diagnostico prequirurgico_L039',
#        'cod diagnostico prequirurgico_M500',
#        'cod diagnostico prequirurgico_M861',
#        'cod diagnostico prequirurgico_M866',
#        'cod diagnostico prequirurgico_T818',
#        'cod diagnostico prequirurgico_T845',
#        'cod diagnostico prequirurgico_Y838', 'codigo eps',
#        'complicaciones', 'edad', 'especialidad_cirugia general',
#        'especialidad_endovascular (hemodinamia)',
#        'especialidad_ortopedia', 'frecuencia cardíaca en reposo', 'idcx',
#        'imc', 'ingreso', 'mes', 'mets -índice metabólico',
#        'origen admsion_urgencias generales sotano', 'perímetro cintura',
#        'perímetro muslo', 'peso', 'pliegue abdomen', 'pliegue muslo',
#        'pliegue triceps', 'presión arterial diastólica',
#        'presión arterial sistólica', 'procedimiento 0256', 'quirofano',
#        'requiere cita de morbilidad_Si', 'saturación de oxígeno (%)',
#        'sexo_m', 'sumatoria pliegues', 'talla',
#        'tiempo en segundos (apoyo monopodal)',
#        'tipo aislamiento_CONTACTO;', 'tipo de herida_contaminada',
#        'tipo de herida_limpia', 'tipo de herida_limpia contaminada',
#        'tipo de herida_sin informe quirurgico', 'tipo de herida_sucia',
#        'velocidad (m/s)', 'via_unica via',
#        'vo2 - máxima cantidad de oxígeno',
#        'índice de fragilidad groningen'], dtype=object)

# %%
X2=X[var_names] ### matriz con variables seleccionadas

# %%
def medir_modelos(modelos,scoring,X,y,cv,cross_val_score,pd):

    metric_modelos=pd.DataFrame()
    for modelo in modelos:
        scores=cross_val_score(modelo,X,y, scoring=scoring, cv=cv )
        pdscores=pd.DataFrame(scores)
        metric_modelos=pd.concat([metric_modelos,pdscores],axis=1)
    
    metric_modelos.columns=["reg_lineal","decision_tree","random_forest","gradient_boosting"]
    return metric_modelos

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score, cross_validate
import matplotlib.pyplot as plt ### gráficos

# %%
mape_varsel= medir_modelos(modelos,"neg_mean_absolute_percentage_error",X2,y,10, cross_val_score, pd)
rmse_varsel= medir_modelos(modelos,"neg_root_mean_squared_error",X2,y,10, cross_val_score, pd)

# %%
mape_varsel.plot(kind='box')

# %%
modelos2=list([m_rtree, m_rf, m_gbt])
def medir_modelos(modelos2,scoring,X,y,cv,cross_val_score,pd):

    metric_modelos=pd.DataFrame()
    for modelo in modelos2:
        scores=cross_val_score(modelo,X,y, scoring=scoring, cv=cv )
        pdscores=pd.DataFrame(scores)
        metric_modelos=pd.concat([metric_modelos,pdscores],axis=1)
    
    metric_modelos.columns=["m_rtree","m_rf","m_gbt"]
    return metric_modelos

score22 = medir_modelos(modelos2,"neg_mean_absolute_percentage_error",X2,y,10, cross_val_score, pd)

score22.columns=['m_rtree', 'm_rf', 'm_gbt']
score22.plot(kind='box')

#seleccionamos RandomForestRegressor

# %%
#Hiperparametros
param_grid = [{'n_estimators': [3, 500, 100], 'max_features': [5,20]},
{'bootstrap': [False,True]}]


tun_rf=RandomizedSearchCV(m_rf,param_distributions=param_grid,n_iter=8,scoring="neg_root_mean_squared_error")
tun_rf.fit(X2,y)

resultados=tun_rf.cv_results_
tun_rf.best_params_
pd_resultados=pd.DataFrame(resultados)
pd_resultados[["params","mean_test_score"]]

rf_final=tun_rf.best_estimator_ ### Guardar el modelo con hyperparameter tunning
m_lreg=m_lreg.fit(X2,y)

# %%
pd_resultados[["params","mean_test_score"]]
# Out:
#                                       params  mean_test_score
# 0     {'n_estimators': 3, 'max_features': 5}        -1.288860
# 1   {'n_estimators': 500, 'max_features': 5}        -1.090817
# 2   {'n_estimators': 100, 'max_features': 5}        -1.084040
# 3    {'n_estimators': 3, 'max_features': 20}        -1.223295
# 4  {'n_estimators': 500, 'max_features': 20}        -1.096720
# 5  {'n_estimators': 100, 'max_features': 20}        -1.118753
# 6                       {'bootstrap': False}        -1.320635
# 7                        {'bootstrap': True}        -1.114563

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
eval=cross_validate(rf_final,X2,y,cv=5,scoring="neg_root_mean_squared_error",return_train_score=True)

# %%
train_rf=pd.DataFrame(eval['train_score'])
test_rf=pd.DataFrame(eval['test_score'])
train_test_rf=pd.concat([train_rf, test_rf],axis=1)
train_test_rf.columns=['train_score','test_score']

# %%
train_test_rf["test_score"].mean()
# Out:
# -1.0890586246963305

# %%
predictions=cross_val_predict(m_lreg,X2,y,cv=5)
predictions.shape
# Out:
# (705,)

# %%
pred=pd.DataFrame(predictions,columns=['pred'])
pdy=y.to_frame()
error=pdy['cantidad de cirugias']-pred['pred']
error.hist(bins=50)

# %%
plt.boxplot(error,vert=False)
plt.show()

# %%
#Evaluación de overfitting y underfitting
results = cross_validate(rf_final,X2,y,return_train_score=True,cv=5) 
results
test_scores = results['test_score']
train_scores = results['train_score']
#score de entrenamiento
print(np.mean(train_scores)) 
#score de prueba
print(np.mean(test_scores))
# Out:
# 0.8826241046878094
# 0.15967670979843515

# %%
##### Mirar importancia de variables para tomar acciones ###

importancia1=pd.DataFrame( m_lreg.feature_names_in_)
importancia2=pd.DataFrame(m_lreg.coef_)
importancia=pd.concat([importancia1,importancia2],axis=1)
importancia.columns=["variable","peso"]


importancia.sort_values(by=["peso"])
# Out:
#                                   variable          peso
# 108  tipo de herida_sin informe quirurgico -1.538499e+06
# 16              cie 10 tercer caracter_K05 -1.140135e+06
# 12              cie 10 tercer caracter_E88 -1.137617e+06
# 37     cod diagnostico postquirurgico_E881 -1.137581e+06
# 57      cod diagnostico prequirurgico_E881 -1.137581e+06
# ..                                     ...           ...
# 31              cie 10 tercer caracter_Y83  4.807649e+05
# 7                   capitulo cie10_V01-Y98  4.808289e+05
# 38     cod diagnostico postquirurgico_I714  6.410246e+05
# 58      cod diagnostico prequirurgico_I714  6.410249e+05
# 13              cie 10 tercer caracter_I71  6.410714e+05
#
# [114 rows x 2 columns]

# %%
# División de los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(
                                        X2,
                                        y,
                                        random_state = 123
                                    )

# %%
#Dataframe con las variables influyentes
importancia_predictores = pd.DataFrame(
                            {'predictor': X_train.columns,
                             'importancia': rf_final.feature_importances_}
                            )
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores.sort_values('importancia', ascending=False)
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#                                predictor   importancia
# 82                                  idcx  3.896861e-02
# 0                               admision  3.875807e-02
# 102                                talla  3.692997e-02
# 112     vo2 - máxima cantidad de oxígeno  3.376059e-02
# 10            cie 10 tercer caracter_E13  3.364235e-02
# ..                                   ...           ...
# 13            cie 10 tercer caracter_I71  4.658132e-06
# 15            cie 10 tercer caracter_K04  1.584632e-06
# 17            cie 10 tercer caracter_K11  1.576394e-06
# 34   cod diagnostico postquirurgico_D179  6.522904e-07
# 76                        complicaciones  0.000000e+00
#
# [114 rows x 2 columns]

# %%
from sklearn.inspection import permutation_importance

# %%
pd_pred=pd.DataFrame(predictions[:705])
pd_pred.shape
# Out:
# (705, 1)

# %%
df =pd_pred
df.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df=df.round()

# %%
df1 = df.rename(columns={'0':'Cantidad de Cirugias prediccion'},inplace=True)
df1

# %%
ID=dfcx2["nrodoc"]
ID=pd.DataFrame(ID).reset_index()
ID
# Out:
#      index  nrodoc
# 0        0  306221
# 1       18  306230
# 2       31  306233
# 3       49  306259
# 4       67  306271
# ..     ...     ...
# 700  11757  314120
# 701  11763  314125
# 702  11769  314172
# 703  11774  314182
# 704  11779  314187
#
# [705 rows x 2 columns]

# %%
ID=ID.drop(["index"],axis=1)

# %%
df.columns=["Cantidad de Cirugias pronosticadas"]
df
# Out:
#      Cantidad de Cirugias pronosticadas
# 0                                   1.0
# 1                                   2.0
# 2                                   1.0
# 3                                   1.0
# 4                                   2.0
# ..                                  ...
# 700                                 1.0
# 701                                 1.0
# 702                                 2.0
# 703                                 1.0
# 704                                 1.0
#
# [705 rows x 1 columns]

# %%
perf_pred=pd.concat([ID,df],axis=1)

# %%
perf_pred
# Out:
#      nrodoc  Cantidad de Cirugias pronosticadas
# 0    306221                                 1.0
# 1    306230                                 2.0
# 2    306233                                 1.0
# 3    306259                                 1.0
# 4    306271                                 2.0
# ..      ...                                 ...
# 700  314120                                 1.0
# 701  314125                                 1.0
# 702  314172                                 2.0
# 703  314182                                 1.0
# 704  314187                                 1.0
#
# [705 rows x 2 columns]
